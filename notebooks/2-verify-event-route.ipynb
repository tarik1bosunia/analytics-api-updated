# %%
import requests
from pprint import pprint

path = "/api/events"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response = requests.get(endpoint)
response.ok
# Out:
# True

# %%
if response.ok:
    data = response.json()
    pprint(data)
    print(type(data))
# Out:
# {'count': 2,
#  'results': [{'created_at': '2025-11-17T06:06:39.879248Z',
#               'description': 'd e s c r i p t i o n updated',
#               'id': 2,
#               'page': '/test+ dddddddddddddddd',
#               'updated_at': '2025-11-17T06:14:17.292880Z'},
#              {'created_at': '2025-11-17T06:06:39.865033Z',
#               'description': 'd e s c r i p t i o n 3',
#               'id': 1,
#               'page': '/test+ dddddddddddddddd',
#               'updated_at': '2025-11-17T06:08:16.485221Z'}]}
# <class 'dict'>

# %%
path = "/api/events/2"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events/2'

# %%
response = requests.get(endpoint)
print(response.ok)
print(response.status_code)
print(response.text)
if response.ok:
    data = response.json()
    pprint(data)
    print(type(data))
# Out:
# True
# 200
# {"page":"/test+ dddddddddddddddd","created_at":"2025-11-17T06:06:39.879248Z","updated_at":"2025-11-17T06:14:17.292880Z","id":2,"description":"d e s c r i p t i o n updated"}
# {'created_at': '2025-11-17T06:06:39.879248Z',
#  'description': 'd e s c r i p t i o n updated',
#  'id': 2,
#  'page': '/test+ dddddddddddddddd',
#  'updated_at': '2025-11-17T06:14:17.292880Z'}
# <class 'dict'>
