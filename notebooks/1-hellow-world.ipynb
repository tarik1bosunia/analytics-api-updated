# %%
print("hi")
# Out:
# hi

# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in /home/tata/tarik/analytics api/venv/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/tata/tarik/analytics api/venv/lib/python3.12/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/tata/tarik/analytics api/venv/lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tata/tarik/analytics api/venv/lib/python3.12/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tata/tarik/analytics api/venv/lib/python3.12/site-packages (from requests) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
path = "/healthz"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/healthz'

# %%
response = requests.get(endpoint)
response.ok
# Out:
# True
