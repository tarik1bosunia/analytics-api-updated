# %%
import requests

path = "/api/events"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8000/api/events'

# %%
data = {
    "page": "/test+"
}

# %%
import json

# %%
response = requests.post(endpoint, json=data)
response.ok
# Out:
# True

# %%
headers = {
    "Content-Type": "application/json"
}

response = requests.post(endpoint, data=json.dumps(data), headers=headers)
response.ok
# Out:
# True

# %%
print(response.text)
print(response.headers)
if response.ok:
    data = response.json()
    print(data)
    print(type(data))
# Out:
# {"description":"","id":3,"page":"/test+"}
# {'date': 'Sun, 16 Nov 2025 13:39:36 GMT', 'server': 'uvicorn', 'content-length': '41', 'content-type': 'application/json'}
# {'description': '', 'id': 3, 'page': '/test+'}
# <class 'dict'>

# %%
import requests

detail_path = "/api/events/12"
detail_endpoint = f"{base_url}{detail_path}"
detail_endpoint
# Out:
# 'http://localhost:8002/api/events/12'

# %%
headers = {
    "Content-Type": "application/json"
}

data = {
    "description": "d e s c r i p t i o n"
}

response = requests.put(detail_endpoint, json=data)


print(response.headers)
if response.ok:
    data = response.json()
    print(data)
    print(type(data))
else:
    print(response.text)
# Out:
# {'date': 'Sun, 16 Nov 2025 12:32:03 GMT', 'server': 'uvicorn', 'content-length': '57', 'content-type': 'application/json'}
# {'id': 12, 'page': '', 'description': 'd e s c r i p t i o n'}
# <class 'dict'>
